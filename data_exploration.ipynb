# %% [markdown]
# # Exploring kaggle dataset: 120 years of Olympic history: athletes and results
# ***containing:*** bio data on athletes and medal results from Athens 1896 to Rio 2016

# %% [markdown]
# ***Notes:***
# * Winter olympics started in  1924
# * Following 1992 winter and summer olympics were no longer held on the same year

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# increase width of cells in notebook
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns

plt.rcParams["figure.dpi"] = 130
plt.rcParams["figure.figsize"] = (8,4)
plt.rc('text', usetex=True)
plt.rc('font', family='sans-serif')

# %% [markdown]
# ## Parsing .csv's to dataframes, and previewing

# %%
events_df = pd.read_csv('./data/athlete_events.csv')
regions_df = pd.read_csv('./data/noc_regions.csv')

# %%
print(events_df.shape)
events_df.head()
# Out:
# (271116, 15)
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %%
events_df.info()

# result: missing values for: height, weight, age and medals
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
# ID        271116 non-null int64
# Name      271116 non-null object
# Sex       271116 non-null object
# Age       261642 non-null float64
# Height    210945 non-null float64
# Weight    208241 non-null float64
# Team      271116 non-null object
# NOC       271116 non-null object
# Games     271116 non-null object
# Year      271116 non-null int64
# Season    271116 non-null object
# City      271116 non-null object
# Sport     271116 non-null object
# Event     271116 non-null object
# Medal     39783 non-null object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
events_df.describe()

# max age: 97? -- investigate this further
# min age: 10 -- investigate
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %%
print(regions_df.shape)
regions_df.head()

# result: this maps NOC code to a region, with notes
# Out:
# (230, 3)
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
regions_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230 entries, 0 to 229
# Data columns (total 3 columns):
# NOC       230 non-null object
# region    227 non-null object
# notes     21 non-null object
# dtypes: object(3)
# memory usage: 5.5+ KB

# %% [markdown]
# ### Merging events_df and regions_df

# %%
print(events_df.columns)
print(regions_df.columns)
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')
# Index(['NOC', 'region', 'notes'], dtype='object')

# %%
merged_df = events_df.merge(regions_df, on='NOC', how='outer')

# %%
merged_df.head()
# Out:
#        ID           Name Sex   Age  Height  Weight   Team  NOC        Games  \
# 0     1.0      A Dijiang   M  24.0   180.0    80.0  China  CHN  1992 Summer
# 1     2.0       A Lamusi   M  23.0   170.0    60.0  China  CHN  2012 Summer
# 2   602.0  Abudoureheman   M  22.0   182.0    75.0  China  CHN  2000 Summer
# 3  1463.0      Ai Linuer   M  25.0   160.0    62.0  China  CHN  2004 Summer
# 4  1464.0      Ai Yanhan   F  14.0   168.0    54.0  China  CHN  2016 Summer
#
#      Year  Season            City       Sport  \
# 0  1992.0  Summer       Barcelona  Basketball
# 1  2012.0  Summer          London        Judo
# 2  2000.0  Summer          Sydney      Boxing
# 3  2004.0  Summer          Athina   Wrestling
# 4  2016.0  Summer  Rio de Janeiro    Swimming
#
#                                       Event Medal region notes
# 0               Basketball Men's Basketball   NaN  China   NaN
# 1              Judo Men's Extra-Lightweight   NaN  China   NaN
# 2                 Boxing Men's Middleweight   NaN  China   NaN
# 3  Wrestling Men's Lightweight, Greco-Roman   NaN  China   NaN
# 4     Swimming Women's 200 metres Freestyle   NaN  China   NaN

# %% [markdown]
# ## Most Successful Teams
# * top medal winning countries

# %%
# Medals for all olympics
# groupby region, instead of team, to include historical teams
# TODO: mention this in the report under observations
medals = merged_df[(merged_df['Medal'].notnull())].groupby('region')['Medal'].value_counts().unstack()
medals.head()
# Out:
# Medal        Bronze   Gold  Silver
# region
# Afghanistan     2.0    NaN     NaN
# Algeria         8.0    5.0     4.0
# Argentina      91.0   91.0    92.0
# Armenia         9.0    2.0     5.0
# Australia     522.0  368.0   459.0

# %%
# total medals, ordering by total
total_medals = medals.sum(axis=1)
medals['total'] = total_medals
medals = medals.sort_values('total', ascending=False)
medals_wo_total = medals[['Bronze', 'Silver', 'Gold']]

# taking top 20
medals_wo_total = medals_wo_total.iloc[:20]

# plotting
medals_wo_total.plot(kind='bar', stacked=True, color=['burlywood', 'silver', 'gold'])
plt.ylabel('Medal Count')
plt.xlabel('Region')
plt.title('Top 20 Medal Winning Countries')

# result: this must be because the USA has a lot of participants
# how does this success look when normalised for number of entrants?
# Out:
# Text(0.5,1,'Top 20 Medal Winning Countries')

# %%
# total participants for each region
total_participants = merged_df.groupby('region')['ID'].count()

# %%
medals.head()
# Out:
# Medal    Bronze    Gold  Silver   total
# region
# USA      1358.0  2638.0  1641.0  5637.0
# Russia   1178.0  1599.0  1170.0  3947.0
# Germany  1260.0  1301.0  1195.0  3756.0
# UK        651.0   678.0   739.0  2068.0
# France    666.0   501.0   610.0  1777.0

# %%
# adding total participants to dataframe
medals = medals.join(total_participants, how='outer')
medals.head()
# Out:
#                 Bronze  Gold  Silver  total   ID
# region
# Afghanistan        2.0   NaN     NaN    2.0  126
# Albania            NaN   NaN     NaN    NaN   70
# Algeria            8.0   5.0     4.0   17.0  551
# American Samoa     NaN   NaN     NaN    NaN   37
# Andorra            NaN   NaN     NaN    NaN  169

# %%
# total medals per entrant
medals['medals_per_entrant'] = medals['total'] / medals['ID']
medals_per_entrant = medals.sort_values('medals_per_entrant', ascending=False)

# %%
# medals per entrant

medals_per_entrant = medals_per_entrant[['medals_per_entrant']].iloc[:20]

# plotting
medals_per_entrant.plot(kind='bar', stacked=True, legend=False)
plt.ylabel('Medals per Entrant')
plt.xlabel('Region')
plt.title('Top 20 Medal Per Entrant Countries')

# Result: Pakistan is an odd region to see here
# TODO: add a normalised percentage corresponding to medals
# Out:
# Text(0.5,1,'Top 20 Medal Per Entrant Countries')

# %%
# what sports are pakistan most successful in?
merged_df[(merged_df['region']=='Pakistan') & (merged_df['Medal']).notnull()]['Sport'].value_counts()
# result: medal count includes 1 medal for each member of team
# Out:
# Hockey       119
# Boxing         1
# Wrestling      1
# Name: Sport, dtype: int64

# %%
# pakistan medals for each year
merged_df[(merged_df['region']=='Pakistan') & (merged_df['Medal']).notnull()].groupby('Year')['Event'].value_counts()

# result: not counting teams, this should be 10 medals
# Out:
# Year    Event
# 1956.0  Hockey Men's Hockey                        14
# 1960.0  Hockey Men's Hockey                        13
#         Wrestling Men's Welterweight, Freestyle     1
# 1964.0  Hockey Men's Hockey                        16
# 1968.0  Hockey Men's Hockey                        13
# 1972.0  Hockey Men's Hockey                        15
# 1976.0  Hockey Men's Hockey                        16
# 1984.0  Hockey Men's Hockey                        16
# 1988.0  Boxing Men's Middleweight                   1
# 1992.0  Hockey Men's Hockey                        16
# Name: Event, dtype: int64

# %% [markdown]
# ## Can we reduce all team events to 1 medal?

# %%
merged_df[(merged_df['Year']==1896) & (merged_df['Event']=="Athletics Men's High Jump")]
# Out:
#               ID                           Name Sex   Age  Height  Weight  \
# 17364    21795.0           Ellery Harding Clark   M  22.0   180.0     NaN
# 17667    22700.0  James Brendan Bennet Connolly   M  27.0   175.0    72.0
# 20293    38860.0           Robert "Bob" Garrett   M  20.0   188.0    81.0
# 126045   49185.0                  Fritz Hofmann   M  24.0   167.0    56.0
# 197410  111499.0  Kristian Henrik Rudolf Sjberg   M  21.0     NaN     NaN
#
#                  Team  NOC        Games    Year  Season    City      Sport  \
# 17364   United States  USA  1896 Summer  1896.0  Summer  Athina  Athletics
# 17667   United States  USA  1896 Summer  1896.0  Summer  Athina  Athletics
# 20293   United States  USA  1896 Summer  1896.0  Summer  Athina  Athletics
# 126045        Germany  GER  1896 Summer  1896.0  Summer  Athina  Athletics
# 197410         Sweden  SWE  1896 Summer  1896.0  Summer  Athina  Athletics
#
#                             Event   Medal   region notes
# 17364   Athletics Men's High Jump    Gold      USA   NaN
# 17667   Athletics Men's High Jump  Silver      USA   NaN
# 20293   Athletics Men's High Jump  Silver      USA   NaN
# 126045  Athletics Men's High Jump     NaN  Germany   NaN
# 197410  Athletics Men's High Jump     NaN   Sweden   NaN

# %%
# taking 1 medal for each event
# NOTE: this doesn't take into account draws for medals
medals_wo_team = merged_df[merged_df['Medal'].notnull()]
                    .groupby(['Year', 'Event', 'Medal'])['region']
                    .first().unstack()
medals_wo_team.head()
# Out:
# Medal                                      Bronze       Gold   Silver
# Year   Event
# 1896.0 Athletics Men's 1,500 metres        France  Australia      USA
#        Athletics Men's 100 metres             USA        USA  Germany
#        Athletics Men's 110 metres Hurdles     NaN        USA       UK
#        Athletics Men's 400 metres              UK        USA      USA
#        Athletics Men's 800 metres          Greece  Australia  Hungary

# %%
# combining the above results
medals_bronze = medals_wo_team['Bronze'].value_counts()
medals_silver = medals_wo_team['Silver'].value_counts()
medals_gold = medals_wo_team['Gold'].value_counts()

# %%
# joining the results from above
medals_wo_team_count = pd.concat([medals_bronze, medals_silver, medals_gold], axis=1)
# Out:
# /Users/yasirdin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
# adding total
medals_wo_team_count['total'] = medals_wo_team_count.sum(axis=1)

# %%
# checking pakistan, to see if team hasn't been counted:
medals_wo_team_count[medals_wo_team_count.index=='Pakistan']

# result: it worked!
# Out:
#           Bronze  Silver  Gold  total
# Pakistan     4.0     3.0   3.0   10.0

# %%
# now plotting the adjusted
medals_wo_team_count.sort_values('total', ascending=False).iloc[:20][['Bronze', 'Silver', 'Gold']].plot(kind='bar', 
                                                                                                        stacked=True, 
                                                                                                        color=['burlywood', 'silver', 'gold'])
plt.title('Top 20 Winning Countries (Adjusted for Teams)')
plt.ylabel('Medal Count')
plt.xlabel('Region')
# Out:
# Text(0.5,0,'Region')

# %%
athlete_medals = merged_df[merged_df['Medal'].notnull()].groupby(['Name', 'region', 'Sport'])['Medal'].value_counts().unstack()
athlete_medals['total_medals'] = athlete_medals.sum(axis=1)
athlete_medals = athlete_medals.sort_values('total_medals', ascending=False)
athlete_medals.head()
# Out:
# Medal                                                 Bronze  Gold  Silver  \
# Name                               region Sport
# Michael Fred Phelps, II            USA    Swimming       2.0  23.0     3.0
# Larysa Semenivna Latynina (Diriy-) Russia Gymnastics     4.0   9.0     5.0
# Nikolay Yefimovich Andrianov       Russia Gymnastics     3.0   7.0     5.0
# Edoardo Mangiarotti                Italy  Fencing        2.0   6.0     5.0
# Borys Anfiyanovych Shakhlin        Russia Gymnastics     2.0   7.0     4.0
#
# Medal                                                 total_medals
# Name                               region Sport
# Michael Fred Phelps, II            USA    Swimming            28.0
# Larysa Semenivna Latynina (Diriy-) Russia Gymnastics          18.0
# Nikolay Yefimovich Andrianov       Russia Gymnastics          15.0
# Edoardo Mangiarotti                Italy  Fencing             13.0
# Borys Anfiyanovych Shakhlin        Russia Gymnastics          13.0

# %%
athlete_medals.iloc[:20]
# Out:
# Medal                                                                      Bronze  \
# Name                                            region         Sport
# Michael Fred Phelps, II                         USA            Swimming       2.0
# Larysa Semenivna Latynina (Diriy-)              Russia         Gymnastics     4.0
# Nikolay Yefimovich Andrianov                    Russia         Gymnastics     3.0
# Edoardo Mangiarotti                             Italy          Fencing        2.0
# Borys Anfiyanovych Shakhlin                     Russia         Gymnastics     2.0
# Ole Einar Bjrndalen                             Norway         Biathlon       1.0
# Takashi Ono                                     Japan          Gymnastics     4.0
# Dara Grace Torres (-Hoffman, -Minas)            USA            Swimming       4.0
# Jennifer Elisabeth "Jenny" Thompson (-Cumpelik) USA            Swimming       1.0
# Sawao Kato                                      Japan          Gymnastics     1.0
# Aleksey Yuryevich Nemov                         Russia         Gymnastics     6.0
# Birgit Fischer-Schmidt                          Germany        Canoeing       NaN
# Ryan Steven Lochte                              USA            Swimming       3.0
# Paavo Johannes Nurmi                            Finland        Athletics      NaN
# Natalie Anne Coughlin (-Hall)                   USA            Swimming       5.0
# Vra slavsk (-Odloilov)                          Czech Republic Gymnastics     NaN
# Mark Andrew Spitz                               USA            Swimming       1.0
# Viktor Ivanovych Chukarin                       Russia         Gymnastics     1.0
# Carl Townsend Osburn                            USA            Shooting       2.0
# Matthew Nicholas "Matt" Biondi                  USA            Swimming       1.0
#
# Medal                                                                      Gold  \
# Name                                            region         Sport
# Michael Fred Phelps, II                         USA            Swimming    23.0
# Larysa Semenivna Latynina (Diriy-)              Russia         Gymnastics   9.0
# Nikolay Yefimovich Andrianov                    Russia         Gymnastics   7.0
# Edoardo Mangiarotti                             Italy          Fencing      6.0
# Borys Anfiyanovych Shakhlin                     Russia         Gymnastics   7.0
# Ole Einar Bjrndalen                             Norway         Biathlon     8.0
# Takashi Ono                                     Japan          Gymnastics   5.0
# Dara Grace Torres (-Hoffman, -Minas)            USA            Swimming     4.0
# Jennifer Elisabeth "Jenny" Thompson (-Cumpelik) USA            Swimming     8.0
# Sawao Kato                                      Japan          Gymnastics   8.0
# Aleksey Yuryevich Nemov                         Russia         Gymnastics   4.0
# Birgit Fischer-Schmidt                          Germany        Canoeing     8.0
# Ryan Steven Lochte                              USA            Swimming     6.0
# Paavo Johannes Nurmi                            Finland        Athletics    9.0
# Natalie Anne Coughlin (-Hall)                   USA            Swimming     3.0
# Vra slavsk (-Odloilov)                          Czech Republic Gymnastics   7.0
# Mark Andrew Spitz                               USA            Swimming     9.0
# Viktor Ivanovych Chukarin                       Russia         Gymnastics   7.0
# Carl Townsend Osburn                            USA            Shooting     5.0
# Matthew Nicholas "Matt" Biondi                  USA            Swimming     8.0
#
# Medal                                                                      Silver  \
# Name                                            region         Sport
# Michael Fred Phelps, II                         USA            Swimming       3.0
# Larysa Semenivna Latynina (Diriy-)              Russia         Gymnastics     5.0
# Nikolay Yefimovich Andrianov                    Russia         Gymnastics     5.0
# Edoardo Mangiarotti                             Italy          Fencing        5.0
# Borys Anfiyanovych Shakhlin                     Russia         Gymnastics     4.0
# Ole Einar Bjrndalen                             Norway         Biathlon       4.0
# Takashi Ono                                     Japan          Gymnastics     4.0
# Dara Grace Torres (-Hoffman, -Minas)            USA            Swimming       4.0
# Jennifer Elisabeth "Jenny" Thompson (-Cumpelik) USA            Swimming       3.0
# Sawao Kato                                      Japan          Gymnastics     3.0
# Aleksey Yuryevich Nemov                         Russia         Gymnastics     2.0
# Birgit Fischer-Schmidt                          Germany        Canoeing       4.0
# Ryan Steven Lochte                              USA            Swimming       3.0
# Paavo Johannes Nurmi                            Finland        Athletics      3.0
# Natalie Anne Coughlin (-Hall)                   USA            Swimming       4.0
# Vra slavsk (-Odloilov)                          Czech Republic Gymnastics     4.0
# Mark Andrew Spitz                               USA            Swimming       1.0
# Viktor Ivanovych Chukarin                       Russia         Gymnastics     3.0
# Carl Townsend Osburn                            USA            Shooting       4.0
# Matthew Nicholas "Matt" Biondi                  USA            Swimming       2.0
#
# Medal                                                                      total_medals
# Name                                            region         Sport
# Michael Fred Phelps, II                         USA            Swimming            28.0
# Larysa Semenivna Latynina (Diriy-)              Russia         Gymnastics          18.0
# Nikolay Yefimovich Andrianov                    Russia         Gymnastics          15.0
# Edoardo Mangiarotti                             Italy          Fencing             13.0
# Borys Anfiyanovych Shakhlin                     Russia         Gymnastics          13.0
# Ole Einar Bjrndalen                             Norway         Biathlon            13.0
# Takashi Ono                                     Japan          Gymnastics          13.0
# Dara Grace Torres (-Hoffman, -Minas)            USA            Swimming            12.0
# Jennifer Elisabeth "Jenny" Thompson (-Cumpelik) USA            Swimming            12.0
# Sawao Kato                                      Japan          Gymnastics          12.0
# Aleksey Yuryevich Nemov                         Russia         Gymnastics          12.0
# Birgit Fischer-Schmidt                          Germany        Canoeing            12.0
# Ryan Steven Lochte                              USA            Swimming            12.0
# Paavo Johannes Nurmi                            Finland        Athletics           12.0
# Natalie Anne Coughlin (-Hall)                   USA            Swimming            12.0
# Vra slavsk (-Odloilov)                          Czech Republic Gymnastics          11.0
# Mark Andrew Spitz                               USA            Swimming            11.0
# Viktor Ivanovych Chukarin                       Russia         Gymnastics          11.0
# Carl Townsend Osburn                            USA            Shooting            11.0
# Matthew Nicholas "Matt" Biondi                  USA            Swimming            11.0

# %%
# Michael Phelps does everything in the water.. what if he normalise by medals / events competed in?

# getting events participated in, including instances where medals were not won
num_events = merged_df.groupby(['Name', 'Games'])['Event'].count().unstack()
num_events['total_events'] = num_events.sum(axis=1)
num_events = num_events[['total_events']]

# %%
# adding total_events to the df and orering by total medals one
athlete_medals = athlete_medals.reset_index().set_index('Name').join(num_events).sort_values('total_medals', ascending=False)
athlete_medals.head()
# Out:
#                                     region       Sport  Bronze  Gold  Silver  \
# Name
# Michael Fred Phelps, II                USA    Swimming     2.0  23.0     3.0
# Larysa Semenivna Latynina (Diriy-)  Russia  Gymnastics     4.0   9.0     5.0
# Nikolay Yefimovich Andrianov        Russia  Gymnastics     3.0   7.0     5.0
# Edoardo Mangiarotti                  Italy     Fencing     2.0   6.0     5.0
# Borys Anfiyanovych Shakhlin         Russia  Gymnastics     2.0   7.0     4.0
#
#                                     total_medals  total_events
# Name
# Michael Fred Phelps, II                     28.0          30.0
# Larysa Semenivna Latynina (Diriy-)          18.0          19.0
# Nikolay Yefimovich Andrianov                15.0          24.0
# Edoardo Mangiarotti                         13.0          14.0
# Borys Anfiyanovych Shakhlin                 13.0          24.0

# %%
# adding medals per event 
athlete_medals['medals_per_event'] = athlete_medals['total_medals'] / athlete_medals['total_events']

# %%
athlete_medals.head(20)
# impressive strike rate for the top 2
# Out:
#                                                          region       Sport  \
# Name
# Michael Fred Phelps, II                                     USA    Swimming
# Larysa Semenivna Latynina (Diriy-)                       Russia  Gymnastics
# Nikolay Yefimovich Andrianov                             Russia  Gymnastics
# Edoardo Mangiarotti                                       Italy     Fencing
# Borys Anfiyanovych Shakhlin                              Russia  Gymnastics
# Ole Einar Bjrndalen                                      Norway    Biathlon
# Takashi Ono                                               Japan  Gymnastics
# Dara Grace Torres (-Hoffman, -Minas)                        USA    Swimming
# Jennifer Elisabeth "Jenny" Thompson (-Cumpelik)             USA    Swimming
# Sawao Kato                                                Japan  Gymnastics
# Aleksey Yuryevich Nemov                                  Russia  Gymnastics
# Birgit Fischer-Schmidt                                  Germany    Canoeing
# Ryan Steven Lochte                                          USA    Swimming
# Paavo Johannes Nurmi                                    Finland   Athletics
# Natalie Anne Coughlin (-Hall)                               USA    Swimming
# Vra slavsk (-Odloilov)                           Czech Republic  Gymnastics
# Mark Andrew Spitz                                           USA    Swimming
# Viktor Ivanovych Chukarin                                Russia  Gymnastics
# Carl Townsend Osburn                                        USA    Shooting
# Matthew Nicholas "Matt" Biondi                              USA    Swimming
#
#                                                  Bronze  Gold  Silver  \
# Name
# Michael Fred Phelps, II                             2.0  23.0     3.0
# Larysa Semenivna Latynina (Diriy-)                  4.0   9.0     5.0
# Nikolay Yefimovich Andrianov                        3.0   7.0     5.0
# Edoardo Mangiarotti                                 2.0   6.0     5.0
# Borys Anfiyanovych Shakhlin                         2.0   7.0     4.0
# Ole Einar Bjrndalen                                 1.0   8.0     4.0
# Takashi Ono                                         4.0   5.0     4.0
# Dara Grace Torres (-Hoffman, -Minas)                4.0   4.0     4.0
# Jennifer Elisabeth "Jenny" Thompson (-Cumpelik)     1.0   8.0     3.0
# Sawao Kato                                          1.0   8.0     3.0
# Aleksey Yuryevich Nemov                             6.0   4.0     2.0
# Birgit Fischer-Schmidt                              NaN   8.0     4.0
# Ryan Steven Lochte                                  3.0   6.0     3.0
# Paavo Johannes Nurmi                                NaN   9.0     3.0
# Natalie Anne Coughlin (-Hall)                       5.0   3.0     4.0
# Vra slavsk (-Odloilov)                              NaN   7.0     4.0
# Mark Andrew Spitz                                   1.0   9.0     1.0
# Viktor Ivanovych Chukarin                           1.0   7.0     3.0
# Carl Townsend Osburn                                2.0   5.0     4.0
# Matthew Nicholas "Matt" Biondi                      1.0   8.0     2.0
#
#                                                  total_medals  total_events  \
# Name
# Michael Fred Phelps, II                                  28.0          30.0
# Larysa Semenivna Latynina (Diriy-)                       18.0          19.0
# Nikolay Yefimovich Andrianov                             15.0          24.0
# Edoardo Mangiarotti                                      13.0          14.0
# Borys Anfiyanovych Shakhlin                              13.0          24.0
# Ole Einar Bjrndalen                                      13.0          27.0
# Takashi Ono                                              13.0          33.0
# Dara Grace Torres (-Hoffman, -Minas)                     12.0          13.0
# Jennifer Elisabeth "Jenny" Thompson (-Cumpelik)          12.0          17.0
# Sawao Kato                                               12.0          24.0
# Aleksey Yuryevich Nemov                                  12.0          21.0
# Birgit Fischer-Schmidt                                   12.0          13.0
# Ryan Steven Lochte                                       12.0          14.0
# Paavo Johannes Nurmi                                     12.0          12.0
# Natalie Anne Coughlin (-Hall)                            12.0          12.0
# Vra slavsk (-Odloilov)                                   11.0          18.0
# Mark Andrew Spitz                                        11.0          12.0
# Viktor Ivanovych Chukarin                                11.0          16.0
# Carl Townsend Osburn                                     11.0          16.0
# Matthew Nicholas "Matt" Biondi                           11.0          12.0
#
#                                                  medals_per_event
# Name
# Michael Fred Phelps, II                                  0.933333
# Larysa Semenivna Latynina (Diriy-)                       0.947368
# Nikolay Yefimovich Andrianov                             0.625000
# Edoardo Mangiarotti                                      0.928571
# Borys Anfiyanovych Shakhlin                              0.541667
# Ole Einar Bjrndalen                                      0.481481
# Takashi Ono                                              0.393939
# Dara Grace Torres (-Hoffman, -Minas)                     0.923077
# Jennifer Elisabeth "Jenny" Thompson (-Cumpelik)          0.705882
# Sawao Kato                                               0.500000
# Aleksey Yuryevich Nemov                                  0.571429
# Birgit Fischer-Schmidt                                   0.923077
# Ryan Steven Lochte                                       0.857143
# Paavo Johannes Nurmi                                     1.000000
# Natalie Anne Coughlin (-Hall)                            1.000000
# Vra slavsk (-Odloilov)                                   0.611111
# Mark Andrew Spitz                                        0.916667
# Viktor Ivanovych Chukarin                                0.687500
# Carl Townsend Osburn                                     0.687500
# Matthew Nicholas "Matt" Biondi                           0.916667

# %% [markdown]
# # Reviewing missing data in the dataset
# * data missing for:
#     * height
#     * weight
#     * medals
#
# To start, let's check the years where there exists missing data

# %%
# height
merged_df[merged_df['Height'].isnull()]['Year'].unique()
# Out:
# array([1936., 1948., 1980., 1984., 1992., 2008., 1988., 1932., 1994.,
#        1998., 1996., 2002., 1952., 1920., 1900., 1908., 1928., 1912.,
#        1956., 1906., 1924., 1960., 1896., 2014., 1972., 1976., 1964.,
#        1904., 2016., 2000., 2004., 1968., 2012., 2006., 2010.,   nan])

# %%
# weight 
merged_df[merged_df['Weight'].isnull()]['Year'].unique()
# Out:
# array([1980., 1984., 1936., 2002., 1948., 1992., 2008., 1988., 1932.,
#        1994., 1998., 1996., 1952., 1920., 1900., 1908., 1928., 1912.,
#        1956., 1906., 1924., 1972., 2012., 2014., 1960., 1896., 1976.,
#        1964., 1904., 2016., 2006., 2000., 2004., 1968., 2010.,   nan])

# %%
# medals
merged_df[merged_df['Medal'].isnull()]['Year'].unique()
# Out:
# array([1992., 2012., 2000., 2004., 2016., 2006., 1998., 2008., 1996.,
#        2014., 1984., 1936., 1980., 1988., 2010., 2002., 1948., 1994.,
#        1932., 1952., 1920., 1908., 1972., 1928., 1956., 1912., 1960.,
#        1924., 1964., 1976., 1968., 1906., 1900., 1896., 1904.,   nan])

# %% [markdown]
# ### Is it possible to calculate how many medals should have been awarded at each olympics, given the Events list?
# (Doing this will allow us to guage how much of the medal data is missing.)
#
# ***summary of findings:***
# * cannot simply take Events and multiply by 3 to get total medals
# * there are team sports where the no. of medals is >3

# %%
# checking the events held per year, could use this as an indicator for how many medals SHOULD have been awarded
events_group = merged_df.groupby('Year')['Event'].unique()
events_group.head()
# Out:
# Year
# 1896.0    [Weightlifting Men's Unlimited, One Hand, Weig...
# 1900.0    [Tug-Of-War Men's Tug-Of-War, Fencing Men's Fo...
# 1904.0    [Rowing Men's Coxed Eights, Golf Men's Individ...
# 1906.0    [Football Men's Football, Gymnastics Men's Tea...
# 1908.0    [Athletics Men's Hammer Throw, Wrestling Men's...
# Name: Event, dtype: object

# %%
# assuming bronze, silver and gold is awarded for every event
num_of_events = {}
for ix, events in enumerate(events_group.values, 0):
    # multiply by 3 for bronze, silver, gold
    year = events_group.index[ix]
    num_of_events[year] = len(events) * 3
print(num_of_events)
# Out:
# {1896.0: 129, 1900.0: 270, 1904.0: 285, 1906.0: 222, 1908.0: 327, 1912.0: 321, 1920.0: 474, 1924.0: 444, 1928.0: 408, 1932.0: 435, 1936.0: 501, 1948.0: 525, 1952.0: 513, 1956.0: 525, 1960.0: 531, 1964.0: 591, 1968.0: 621, 1972.0: 684, 1976.0: 705, 1980.0: 723, 1984.0: 780, 1988.0: 849, 1992.0: 942, 1994.0: 183, 1996.0: 813, 1998.0: 204, 2000.0: 900, 2002.0: 234, 2004.0: 903, 2006.0: 252, 2008.0: 906, 2010.0: 258, 2012.0: 906, 2014.0: 294, 2016.0: 918}

# %%
# medals

merged_df.groupby('Year')['Medal'].value_counts(dropna=False)

# result: NaN's mean no medal OR maybe missing data, and there isn't an even award of gold, silver, bronze
# uneven award of medals may be down to ties?
# Out:
# Year    Medal
# 1896.0  NaN         237
#         Gold         62
#         Silver       43
#         Bronze       38
# 1900.0  NaN        1332
#         Silver      228
#         Gold        201
#         Bronze      175
# 1904.0  NaN         815
#         Gold        173
#         Silver      163
#         Bronze      150
# 1906.0  NaN        1275
#         Gold        157
#         Silver      156
#         Bronze      145
# 1908.0  NaN        2270
#         Gold        294
#         Silver      281
#         Bronze      256
# 1912.0  NaN        3099
#         Gold        326
#         Silver      315
#         Bronze      300
# 1920.0  NaN        2984
#         Gold        493
#         Silver      448
#         Bronze      367
# 1924.0  NaN        4731
#         Gold        332
#                   ...
# 2002.0  Bronze      159
#         Silver      157
# 2004.0  NaN       11442
#         Bronze      677
#         Gold        664
#         Silver      660
# 2006.0  NaN        3856
#         Gold        176
#         Bronze      175
#         Silver      175
# 2008.0  NaN       11554
#         Bronze      710
#         Gold        671
#         Silver      667
# 2010.0  NaN        3882
#         Silver      175
#         Gold        174
#         Bronze      171
# 2012.0  NaN       10979
#         Bronze      679
#         Gold        632
#         Silver      630
# 2014.0  NaN        4294
#         Gold        202
#         Bronze      198
#         Silver      197
# 2016.0  NaN       11665
#         Bronze      703
#         Gold        665
#         Silver      655
# Name: Medal, Length: 140, dtype: int64

# %%
# checking events
events_group.iloc[-1]

# result: no trivial way of estimating how many medals are should have been awarded given Events
# this is because some events are team events, wherein many medals are awarded to whole teams
# Out:
# array(["Swimming Women's 200 metres Freestyle",
#        "Swimming Women's 4 x 200 metres Freestyle Relay",
#        "Triathlon Men's Olympic Distance",
#        "Rhythmic Gymnastics Women's Group",
#        "Wrestling Men's Light-Heavyweight, Freestyle",
#        "Athletics Women's Shot Put", "Athletics Men's 20 kilometres Walk",
#        "Archery Women's Individual", "Archery Women's Team",
#        "Athletics Men's Triple Jump",
#        "Shooting Men's Air Rifle, 10 metres",
#        "Shooting Men's Small-Bore Rifle, Prone, 50 metres",
#        "Diving Men's Springboard",
#        "Diving Men's Synchronized Springboard",
#        "Swimming Women's 400 metres Freestyle",
#        "Modern Pentathlon Men's Individual", "Badminton Men's Doubles",
#        "Diving Men's Platform", "Diving Men's Synchronized Platform",
#        "Shooting Women's Trap", "Fencing Men's Foil, Individual",
#        "Fencing Men's Foil, Team",
#        "Swimming Women's 200 metres Backstroke",
#        "Weightlifting Men's Featherweight", "Badminton Men's Singles",
#        "Basketball Women's Basketball", "Sailing Women's Windsurfer",
#        "Modern Pentathlon Women's Individual",
#        "Diving Women's Synchronized Platform",
#        "Swimming Women's 100 metres Butterfly",
#        "Athletics Women's Discus Throw",
#        "Shooting Women's Sporting Pistol, 25 metres",
#        "Judo Men's Middleweight", "Hockey Women's Hockey",
#        "Gymnastics Men's Individual All-Around",
#        "Gymnastics Men's Team All-Around",
#        "Gymnastics Men's Floor Exercise",
#        "Gymnastics Men's Parallel Bars",
#        "Gymnastics Men's Horizontal Bar", "Gymnastics Men's Rings",
#        "Gymnastics Men's Pommelled Horse",
#        "Weightlifting Women's Middleweight",
#        "Wrestling Men's Super-Heavyweight, Freestyle",
#        "Table Tennis Women's Singles", "Table Tennis Women's Team",
#        "Volleyball Women's Volleyball", "Basketball Men's Basketball",
#        "Trampolining Men's Individual", "Athletics Men's Marathon",
#        "Shooting Women's Air Rifle, 10 metres",
#        "Shooting Women's Small-Bore Rifle, Three Positions, 50 metres",
#        "Rowing Women's Single Sculls",
#        "Cycling Men's Team Pursuit, 4,000 metres",
#        "Gymnastics Women's Team All-Around",
#        "Gymnastics Women's Floor Exercise",
#        "Gymnastics Women's Uneven Bars",
#        "Gymnastics Women's Balance Beam", "Golf Women's Individual",
#        "Swimming Women's 100 metres Backstroke",
#        "Swimming Women's 4 x 100 metres Medley Relay",
#        "Football Women's Football", "Athletics Men's Long Jump",
#        "Athletics Women's 4 x 100 metres Relay", "Cycling Women's Sprint",
#        "Cycling Women's Keirin", "Cycling Women's Team Sprint",
#        "Sailing Men's One Person Heavyweight Dinghy",
#        "Synchronized Swimming Women's Team", "Archery Men's Individual",
#        "Archery Men's Team", "Shooting Women's Air Pistol, 10 metres",
#        "Athletics Men's 50 kilometres Walk", "Fencing Women's epee, Team",
#        "Swimming Men's 4 x 100 metres Freestyle Relay",
#        "Trampolining Women's Individual", "Diving Women's Springboard",
#        "Swimming Women's 800 metres Freestyle",
#        "Shooting Men's Double Trap", "Boxing Men's Flyweight",
#        "Boxing Men's Light-Welterweight",
#        "Swimming Men's 200 metres Individual Medley",
#        "Athletics Women's Marathon",
#        'Equestrianism Mixed Three-Day Event, Individual',
#        "Athletics Men's Pole Vault", "Cycling Women's Team Pursuit",
#        "Sailing Women's Two Person Dinghy",
#        "Rowing Women's Lightweight Double Sculls",
#        "Synchronized Swimming Women's Duet",
#        "Shooting Men's Small-Bore Rifle, Three Positions, 50 metres",
#        "Rowing Women's Quadruple Sculls",
#        "Fencing Men's epee, Individual",
#        "Rowing Men's Lightweight Coxless Fours",
#        "Fencing Women's Foil, Individual",
#        "Swimming Men's 100 metres Backstroke",
#        "Swimming Men's 200 metres Backstroke", "Golf Men's Individual",
#        "Athletics Women's Pole Vault", "Athletics Women's Javelin Throw",
#        "Canoeing Women's Kayak Singles, Slalom",
#        "Boxing Women's Middleweight",
#        "Canoeing Men's Canadian Singles, 200 metres",
#        "Swimming Men's 100 metres Breaststroke",
#        "Swimming Men's 200 metres Breaststroke",
#        "Swimming Men's 4 x 100 metres Medley Relay",
#        "Athletics Women's Triple Jump", "Badminton Women's Singles",
#        "Weightlifting Women's Featherweight",
#        "Canoeing Women's Kayak Fours, 500 metres",
#        "Shooting Men's Rapid-Fire Pistol, 25 metres",
#        "Swimming Men's 100 metres Butterfly",
#        "Swimming Men's 200 metres Butterfly",
#        "Athletics Women's 20 kilometres Walk",
#        "Athletics Women's Hammer Throw", "Boxing Men's Welterweight",
#        "Swimming Women's 50 metres Freestyle",
#        "Weightlifting Men's Bantamweight", "Boxing Men's Light-Flyweight",
#        "Weightlifting Men's Middleweight", "Rowing Women's Double Sculls",
#        "Cycling Women's Omnium", "Badminton Women's Doubles",
#        "Judo Men's Half-Lightweight", "Water Polo Women's Water Polo",
#        'Badminton Mixed Doubles', "Table Tennis Men's Singles",
#        "Table Tennis Men's Team",
#        "Canoeing Women's Kayak Doubles, 500 metres",
#        "Judo Women's Half-Lightweight",
#        "Wrestling Men's Super-Heavyweight, Greco-Roman",
#        "Weightlifting Women's Super-Heavyweight",
#        "Rowing Women's Coxless Pairs",
#        "Swimming Men's 50 metres Freestyle",
#        "Swimming Men's 100 metres Freestyle",
#        "Shooting Men's Air Pistol, 10 metres",
#        "Shooting Men's Free Pistol, 50 metres",
#        "Wrestling Men's Light-Heavyweight, Greco-Roman",
#        "Tennis Women's Singles", "Tennis Women's Doubles",
#        "Taekwondo Men's Heavyweight",
#        "Swimming Men's 400 metres Freestyle",
#        "Swimming Men's 1,500 metres Freestyle",
#        "Boxing Women's Flyweight", "Diving Women's Platform",
#        "Judo Men's Lightweight", "Boxing Men's Lightweight",
#        "Gymnastics Women's Individual All-Around",
#        "Swimming Men's 200 metres Freestyle",
#        "Rhythmic Gymnastics Women's Individual",
#        "Fencing Women's Sabre, Individual",
#        "Swimming Women's 100 metres Freestyle",
#        "Swimming Women's 4 x 100 metres Freestyle Relay",
#        "Swimming Women's 100 metres Breaststroke",
#        "Swimming Women's 200 metres Breaststroke",
#        "Diving Women's Synchronized Springboard",
#        "Weightlifting Men's Lightweight",
#        "Canoeing Men's Canadian Singles, Slalom",
#        "Athletics Men's 100 metres",
#        "Athletics Men's 4 x 100 metres Relay",
#        "Rowing Men's Lightweight Double Sculls",
#        "Fencing Men's Sabre, Individual",
#        "Wrestling Women's Flyweight, Freestyle",
#        "Fencing Women's epee, Individual",
#        "Canoeing Men's Kayak Singles, Slalom",
#        "Weightlifting Men's Light-Heavyweight",
#        "Sailing Men's Windsurfer", "Athletics Women's 800 metres",
#        "Beach Volleyball Women's Beach Volleyball",
#        "Triathlon Women's Olympic Distance",
#        "Wrestling Men's Featherweight, Greco-Roman",
#        "Swimming Men's 400 metres Individual Medley",
#        "Sailing Men's Two Person Dinghy",
#        "Gymnastics Women's Horse Vault", "Athletics Men's High Jump",
#        "Cycling Men's Mountainbike, Cross-Country",
#        "Shooting Women's Skeet", "Athletics Women's 100 metres",
#        "Taekwondo Women's Flyweight",
#        "Athletics Women's 100 metres Hurdles",
#        "Weightlifting Women's Light-Heavyweight",
#        "Wrestling Men's Heavyweight, Greco-Roman",
#        "Athletics Men's 110 metres Hurdles",
#        "Swimming Women's 10 kilometres Open Water",
#        "Cycling Men's Sprint", "Sailing Women's One Person Dinghy",
#        "Wrestling Women's Middleweight, Freestyle",
#        "Wrestling Men's Middleweight, Greco-Roman",
#        "Judo Women's Half-Middleweight",
#        "Weightlifting Men's Heavyweight",
#        "Cycling Women's Mountainbike, Cross-Country",
#        "Swimming Women's 200 metres Individual Medley",
#        "Swimming Women's 400 metres Individual Medley",
#        "Wrestling Men's Welterweight, Freestyle",
#        "Boxing Women's Lightweight", "Boxing Men's Heavyweight",
#        "Judo Women's Heavyweight",
#        "Wrestling Women's Heavyweight, Freestyle",
#        "Boxing Men's Bantamweight",
#        "Athletics Women's 3,000 metres Steeplechase",
#        "Swimming Women's 200 metres Butterfly",
#        "Judo Women's Half-Heavyweight", "Boxing Men's Middleweight",
#        "Taekwondo Men's Flyweight", "Taekwondo Women's Heavyweight",
#        "Wrestling Women's Featherweight, Freestyle",
#        "Judo Women's Middleweight",
#        "Wrestling Women's Light-Heavyweight, Freestyle",
#        "Canoeing Women's Kayak Singles, 200 metres",
#        "Canoeing Women's Kayak Singles, 500 metres",
#        "Swimming Men's 10 kilometres Open Water",
#        "Football Men's Football", "Athletics Men's 800 metres",
#        "Cycling Women's BMX", "Handball Men's Handball",
#        'Equestrianism Mixed Dressage, Individual',
#        'Equestrianism Mixed Dressage, Team',
#        "Swimming Men's 4 x 200 metres Freestyle Relay",
#        "Cycling Men's Road Race, Individual", "Sailing Women's Skiff",
#        "Shooting Men's Skeet", "Cycling Men's Omnium",
#        "Sailing Men's One Person Dinghy",
#        "Athletics Men's 3,000 metres Steeplechase",
#        "Cycling Men's Individual Time Trial", "Cycling Men's BMX",
#        "Sailing Men's Skiff", 'Sailing Mixed Multihull',
#        "Canoeing Men's Kayak Singles, 1,000 metres",
#        "Athletics Women's 400 metres Hurdles",
#        "Handball Women's Handball", "Hockey Men's Hockey",
#        "Rowing Women's Coxed Eights", 'Tennis Mixed Doubles',
#        'Equestrianism Mixed Three-Day Event, Team',
#        "Athletics Men's 200 metres", "Athletics Men's 400 metres",
#        "Cycling Men's Keirin", "Cycling Men's Team Sprint",
#        "Rowing Men's Coxless Pairs", "Athletics Men's Decathlon",
#        "Athletics Women's Heptathlon",
#        "Beach Volleyball Men's Beach Volleyball",
#        "Judo Men's Half-Middleweight",
#        "Athletics Women's 4 x 400 metres Relay",
#        'Equestrianism Mixed Jumping, Individual',
#        'Equestrianism Mixed Jumping, Team', "Judo Men's Half-Heavyweight",
#        "Tennis Men's Singles", "Tennis Men's Doubles",
#        "Athletics Women's 1,500 metres", "Rowing Men's Coxed Eights",
#        "Athletics Women's 5,000 metres",
#        "Athletics Women's 10,000 metres", "Rowing Men's Coxless Fours",
#        "Judo Men's Heavyweight", "Judo Men's Extra-Lightweight",
#        "Boxing Men's Light-Heavyweight", "Athletics Women's 200 metres",
#        "Cycling Women's Road Race, Individual",
#        "Cycling Women's Individual Time Trial",
#        "Judo Women's Lightweight", "Fencing Women's Sabre, Team",
#        "Volleyball Men's Volleyball", "Athletics Men's 1,500 metres",
#        "Weightlifting Women's Heavyweight", "Water Polo Men's Water Polo",
#        "Athletics Men's Discus Throw", "Rugby Sevens Men's Rugby Sevens",
#        "Rugby Sevens Women's Rugby Sevens",
#        "Wrestling Men's Middleweight, Freestyle",
#        "Athletics Men's 5,000 metres",
#        "Athletics Men's 400 metres Hurdles",
#        "Athletics Men's 4 x 400 metres Relay", "Athletics Men's Shot Put",
#        "Athletics Men's Javelin Throw", "Athletics Women's High Jump",
#        "Gymnastics Men's Horse Vault", "Athletics Women's Long Jump",
#        "Wrestling Men's Featherweight, Freestyle",
#        "Canoeing Men's Canadian Doubles, Slalom",
#        "Weightlifting Men's Middle-Heavyweight",
#        "Athletics Women's 400 metres", "Athletics Men's Hammer Throw",
#        "Weightlifting Women's Flyweight", "Athletics Men's 10,000 metres",
#        "Taekwondo Men's Welterweight", "Taekwondo Women's Welterweight",
#        "Wrestling Men's Heavyweight, Freestyle",
#        "Taekwondo Women's Featherweight",
#        "Wrestling Women's Lightweight, Freestyle", "Shooting Men's Trap",
#        "Wrestling Men's Welterweight, Greco-Roman",
#        "Rowing Men's Double Sculls", "Rowing Men's Single Sculls",
#        "Boxing Men's Super-Heavyweight", "Judo Women's Extra-Lightweight",
#        "Rowing Men's Quadruple Sculls",
#        "Weightlifting Men's Super-Heavyweight",
#        "Canoeing Men's Canadian Singles, 1,000 metres",
#        "Canoeing Men's Kayak Singles, 200 metres",
#        "Canoeing Men's Kayak Doubles, 200 metres",
#        "Fencing Men's epee, Team",
#        "Canoeing Men's Kayak Fours, 1,000 metres",
#        "Canoeing Men's Kayak Doubles, 1,000 metres",
#        "Taekwondo Men's Featherweight",
#        "Canoeing Men's Canadian Doubles, 1,000 metres",
#        "Weightlifting Women's Lightweight"], dtype=object)

# %% [markdown]
# ### Visualising medal data:

# %%
merged_df.groupby('Year')['Medal'].value_counts().unstack().plot(kind='bar')
plt.title('Olympic games medals')
plt.ylabel('Count')

# result: following 1992 the winter and summer olympics are held on different years -- we can combine these easily
# Out:
# Text(0,0.5,'Count')

# %%
merged_df[merged_df['Season']=='Summer'].groupby('Year')['Medal'].value_counts().unstack().plot(kind='bar')
plt.title('Summer games medals')
plt.ylabel('Count')
# Out:
# Text(0,0.5,'Count')

# %%
merged_df[merged_df['Season']=='Winter'].groupby('Year')['Medal'].value_counts().unstack().plot(kind='bar')
plt.title('Winter Games Medals')
plt.ylabel('Count')
# Out:
# Text(0,0.5,'Count')

# %% [markdown]
# ### what is the age distribution of medalists and how does this compare to the age distribution of all athletes?

# %%
# first, checking missing age values

# number of participants
total_no = merged_df.groupby(['Year']).count()['ID']

# number of participants with age
total_no_with_age = merged_df[merged_df['Age'].notnull()].groupby('Year')['ID'].count()

# total percentage of athletes with height and weight data
percent_with_age = (total_no_with_age/total_no) * 100

# %%
# plotting
fig, ax1 = plt.subplots()

ax1.plot(percent_with_age, 'x-', label='percent w/ age', color='k')
ax1.legend(loc='upper left')
ax1.set_ylabel('With Age (\%)')
ax1.set_ylim(bottom=0, top=110)
ax1.set_xlabel('Year')

ax2 = ax1.twinx()
ax2.plot(total_no, '--x', alpha=0.6, label='total no. of athletes')
ax2.plot(total_no_with_age, '--x', alpha=0.6, label='no. of athletes w/ age')
ax2.legend(loc='lower right')
ax2.set_ylabel('Count', color='#1f77b4')
ax2.tick_params('y', colors='#ff7f0e')

plt.title('Missing Age Data')

# result: be mindful of the missing data in the early years
# Out:
# Text(0.5,1,'Missing Age Data')

# %%
# age distribution of all athletes
all_age = merged_df[(merged_df['Age'].notnull())]['Age'].value_counts()

# weighted average
avg_age_all = np.average(all_age.index, weights=all_age.values)

print(avg_age_all)

print('weighted avg age of all atheletes:', avg_age_all)

# plotting
plt.bar(all_age.index, all_age.values)
plt.title('Age Distribution of All Athletes')
plt.xlabel('Age')
plt.axvline(x=avg_age_all, color='k', linestyle='--', label='weighted average age')
plt.legend()
plt.ylabel('Count')
# Out:
# 25.556898357297374
# weighted avg age of all atheletes: 25.556898357297374
# Text(0,0.5,'Count')

# %%
# age of medalists, for all years
medalists_all = merged_df[(merged_df['Medal'].notnull()) & (merged_df['Age'].notnull())]
# gold
medalists_gold = medalists_all[(medalists_all['Medal']=='Gold')]
# silver
medalists_silver = medalists_all[(medalists_all['Medal']=='Silver')]
# bronze
medalists_bronze = medalists_all[(medalists_all['Medal']=='Bronze')]


medalists_all_age = medalists_all['Age'].value_counts()
medalists_gold_age = medalists_gold['Age'].value_counts()
medalists_silver_age = medalists_silver['Age'].value_counts()
medalists_bronze_age = medalists_bronze['Age'].value_counts()

# weighted average
avg_age_all = np.average(medalists_all_age.index, weights=medalists_all_age.values)
avg_age_gold = np.average(medalists_gold_age.index, weights=medalists_gold_age.values)
avg_age_silver = np.average(medalists_silver_age.index, weights=medalists_silver_age.values)
avg_age_bronze = np.average(medalists_bronze_age.index, weights=medalists_bronze_age.values)

print('weighted avg age of all medalists:', avg_age_all)
print('weighted avg age of gold:', avg_age_gold)
print('weight avg age of silver:', avg_age_silver)
print('weight avg age of bronze:', avg_age_bronze)

# plotting
plt.bar(medalists_all_age.index, medalists_all_age.values)
# plt.bar(medalists_gold_age.index, medalists_gold_age.values, label='gold', alpha=0.5)
# plt.bar(medalists_silver_age.index, medalists_silver_age.values, label='silver', alpha=0.5)
# plt.bar(medalists_bronze_age.index, medalists_bronze_age.values, label='bronze', alpha=0.5)
plt.title('Age Distribution of Medalists Across All Years')
plt.xlabel('Age')
plt.axvline(x=avg_age_all, color='k', linestyle='--', label='weighted average age')
plt.legend()
plt.ylabel('Count')
# Out:
# weighted avg age of all medalists: 25.925174771452717
# weighted avg age of gold: 25.901013309134907
# weight avg age of silver: 25.99672412448327
# weight avg age of bronze: 25.879209595571275
# Text(0,0.5,'Count')

# %%
merged_df['Sex'].value_counts()
# Out:
# M    196594
# F     74522
# Name: Sex, dtype: int64

# %%
# normalising and overlaying age distributions

all_age = merged_df[(merged_df['Age'].notnull())]['Age'].value_counts(normalize=True)
medalists_all_age = medalists_all['Age'].value_counts(normalize=True)

plt.bar(all_age.index, all_age.values, label='all athletes', alpha=0.6)
plt.bar(medalists_all_age.index, medalists_all_age.values, label='medalists', alpha=0.6)


avg_age_medalists = np.average(medalists_all_age.index, weights=medalists_all_age.values)
avg_age_all = np.average(all_age.index, weights=all_age.values)

plt.title('Age Distribution of Medalists Across All Years')
plt.xlabel('Age')
plt.axvline(x=avg_age_medalists, color='k', linestyle='--', label='all medalists avg weighted age')
plt.axvline(x=avg_age_all, color='r', linestyle='--', label='all athletes avg weighted age')
plt.legend()
plt.ylabel('Count')

# result, medalists are actually marginally older, but no significant difference. will need to explore this further per year.
# Out:
# Text(0,0.5,'Count')

# %%
# comparing age distribution of males and females entrants and medalists

# normalise=True to account for discrepancy in male and female involvement
all_age_male = merged_df[(merged_df['Age'].notnull()) & (merged_df['Sex']=='M')]['Age'].value_counts(normalize=True)
all_age_female = merged_df[(merged_df['Age'].notnull()) & (merged_df['Sex']=='F')]['Age'].value_counts(normalize=True)

plt.bar(all_age_male.index, all_age_male.values, label='males', alpha=0.6)
plt.bar(all_age_female.index, all_age_female.values, label='females', alpha=0.6)
plt.title('Age Distribution of all Male and Female Athletes')
plt.xlabel('Age')
plt.legend()
plt.ylabel('Density')
# Out:
# Text(0,0.5,'Density')

# %% [markdown]
# ### Male & Female Involvement

# %%
male_df = events_df[events_df['Sex']=='M']
female_df = events_df[events_df['Sex']=='F']

# %%
male_count = male_df.groupby('Year')['ID'].count()
female_count = female_df.groupby('Year')['ID'].count()

# %%
# adding 0 count to 1896, since no females
female_count = female_count.append(pd.Series([0], index=[1896])).sort_index()

# %%
# ratio
ratio = female_count / male_count

# %%
# plotting
fig, ax1 = plt.subplots()

ax1.plot(ratio, 'x-', label='female to male ratio', color='k')
ax1.legend(loc='upper left')
ax1.set_ylabel('Female / Male')

ax2 = ax1.twinx()
ax2.plot(male_count.index, male_count.values, 'x-', label='male', alpha=0.6)
ax2.plot(female_count.index, female_count.values, 'x-', label='female', alpha=0.6)
ax2.legend(loc='lower right')
ax2.set_ylabel('Count', color='#1f77b4')
ax2.tick_params('y', colors='#ff7f0e')
ax2.set_xlabel('Year')


plt.title('Female / Male Ratio')
# Out:
# Text(0.5,1,'Female / Male Ratio')

# %% [markdown]
# ### Female & Male Age Distribution over time

# %%
# male
males = merged_df[merged_df['Sex']=='M']
plt.figure(figsize=(8,4), dpi=130)
sns.boxplot('Year', 'Age', data=males, palette="vlag")
plt.xticks(rotation='vertical')
plt.title('Male Athlete Age Distribution over Time')

# extreme ages, reviewed later
# Out:
# Text(0.5,1,'Male Athlete Age Distribution over Time')

# %%
# female
females = merged_df[merged_df['Sex']=='F']
plt.figure(figsize=(8,4), dpi=130)
sns.boxplot('Year', 'Age', data=females, palette="vlag")
plt.xticks(rotation='vertical')
plt.title('Female Athlete Age Distribution over Time')
# Out:
# Text(0.5,1,'Female Athlete Age Distribution over Time')

# %%
# standard deviation
plt.plot(males.groupby('Year')['Age'].std(), '-x')
plt.title('Male Age Standard Deviation')
plt.xlabel('Year')
plt.ylabel('Standard Deviation')
# Out:
# Text(0,0.5,'Standard Deviation')

# %%
plt.plot(females.groupby('Year')['Age'].std(), '-x')
plt.title('Female Age Standard Deviation')
plt.xlabel('Year')
plt.ylabel('Standard Deviation')
# Out:
# Text(0,0.5,'Standard Deviation')

# %%
# Standard deviation == standard error
# let's look at top 5 sports over time and see how their age's have changes

# %%
# Looking into 1932 further, as the standard deviation is quite high for both females and males:
merged_df[(merged_df['Year']==1932) & (merged_df['Age']>=70)]['Sport'].value_counts()
# Out:
# Art Competitions    40
# Name: Sport, dtype: int64

# %%
merged_df[(merged_df['Year']==1928) & (merged_df['Age']>=60)]['Sport'].value_counts()
# Out:
# Art Competitions    103
# Equestrianism         2
# Fencing               1
# Name: Sport, dtype: int64

# %%
# so art competitions seem to have caused the shift in age.
# let's look at how the average age has varied for the top .5 sports
top_5_sports = merged_df['Sport'].value_counts().iloc[:5].index
top_5_sports
# Out:
# Index(['Athletics', 'Gymnastics', 'Swimming', 'Shooting', 'Cycling'], dtype='object')

# %%
for sport in top_5_sports:
    avg_age = merged_df[merged_df['Sport']==sport].groupby(['Year'])['Age'].mean()
    plt.plot(avg_age, 'x-', label=sport, alpha=0.6)
plt.title('Average Age For Top 5 Sports')
plt.xlabel('Year')
plt.ylabel('Age')
plt.legend()

# %% [markdown]
# ### Exploring the extreme ages further
# * max age = 97
# * min age = 10

# %%
events_df.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %%
# min age
events_df[events_df['Age']==10]
# Out:
#            ID                Name Sex   Age  Height  Weight  \
# 142882  71691  Dimitrios Loundras   M  10.0     NaN     NaN
#
#                                  Team  NOC        Games  Year  Season    City  \
# 142882  Ethnikos Gymnastikos Syllogos  GRE  1896 Summer  1896  Summer  Athina
#
#              Sport                                  Event   Medal
# 142882  Gymnastics  Gymnastics Men's Parallel Bars, Teams  Bronze

# %%
# max age
events_df[events_df['Age']==97]
# Out:
#             ID                    Name Sex   Age  Height  Weight  \
# 257054  128719  John Quincy Adams Ward   M  97.0     NaN     NaN
#
#                  Team  NOC        Games  Year  Season       City  \
# 257054  United States  USA  1928 Summer  1928  Summer  Amsterdam
#
#                    Sport                                        Event Medal
# 257054  Art Competitions  Art Competitions Mixed Sculpturing, Statues   NaN

# %%
# other young athletes (<=16 years)
under_16 = events_df[events_df['Age']<=16]
under_16.head(2)
# Out:
#       ID                       Name Sex   Age  Height  Weight       Team  NOC  \
# 204   97     Carlos Alberto Abaunza   M  16.0   180.0    70.0  Nicaragua  NCA
# 265  137  Giordano Giulio Abbondati   M  15.0   175.0    64.0      Italy  ITA
#
#            Games  Year  Season       City           Sport  \
# 204  1976 Summer  1976  Summer   Montreal       Athletics
# 265  1964 Winter  1964  Winter  Innsbruck  Figure Skating
#
#                             Event Medal
# 204     Athletics Men's High Jump   NaN
# 265  Figure Skating Men's Singles   NaN

# %%
# top 10 sports:
under_16['Sport'].value_counts().iloc[:10]
# Out:
# Swimming               2898
# Gymnastics             2646
# Figure Skating          239
# Athletics               196
# Alpine Skiing           194
# Diving                  164
# Rhythmic Gymnastics     124
# Rowing                   99
# Speed Skating            69
# Ski Jumping              53
# Name: Sport, dtype: int64

# %%
# since age ditribution is skewed towards younger ages, the threshold for old athletes needs to be higher

# other old athletes (>=70 years)
over_60 = events_df[events_df['Age']>=60]
print(over_60.shape)
over_60.head(2)
# Out:
# (658, 15)
#         ID               Name Sex   Age  Height  Weight    Team  NOC  \
# 2392  1337       Olof Ahlberg   M  71.0     NaN     NaN  Sweden  SWE
# 3944  2278  Emilio lava Sautu   M  63.0     NaN     NaN   Spain  ESP
#
#             Games  Year  Season      City             Sport  \
# 2392  1948 Summer  1948  Summer    London  Art Competitions
# 3944  1952 Summer  1952  Summer  Helsinki          Shooting
#
#                                                Event Medal
# 2392  Art Competitions Mixed Painting, Unknown Event   NaN
# 3944     Shooting Men's Rapid-Fire Pistol, 25 metres   NaN

# %%
over_60['Sport'].value_counts()

# result: art competitions were the most popular amongst old participants
# Out:
# Art Competitions    508
# Shooting             57
# Equestrianism        41
# Sailing              28
# Archery              19
# Fencing               3
# Rowing                1
# Roque                 1
# Name: Sport, dtype: int64

# %%
# years where/when were the art competitions
print('years when art competitions were held:', np.sort(events_df[events_df['Sport']=='Art Competitions']['Year'].unique()))

# number of art events
events_df[events_df['Sport']=='Art Competitions']['Year'].value_counts()
# Out:
# years when art competitions were held: [1912 1920 1924 1928 1932 1936 1948]
# 1932    1124
# 1936     813
# 1928     808
# 1948     471
# 1924     318
# 1912      33
# 1920      11
# Name: Year, dtype: int64

# %%
events_df[events_df['Sport']=='Art Competitions']['Age'].dropna()

# result: about 500 missing age values for the ~3500 participants
# Out:
# 58        54.0
# 669       45.0
# 670       45.0
# 1203      55.0
# 1251      27.0
# 1252      27.0
# 1374      49.0
# 1522      48.0
# 2392      71.0
# 2709      45.0
# 2710      50.0
# 2759      50.0
# 4281      48.0
# 4282      48.0
# 4283      48.0
# 4861      43.0
# 4862      43.0
# 4863      43.0
# 4864      43.0
# 4865      47.0
# 4866      51.0
# 4867      51.0
# 5104      46.0
# 5105      46.0
# 5106      46.0
# 5304      47.0
# 5324      26.0
# 5325      26.0
# 6009      32.0
# 6689      32.0
#           ...
# 267934    41.0
# 267935    41.0
# 267936    41.0
# 267937    41.0
# 267938    41.0
# 267939    41.0
# 267940    41.0
# 267941    41.0
# 267942    41.0
# 267943    41.0
# 267944    45.0
# 267951    36.0
# 268061    38.0
# 268241    23.0
# 268336    38.0
# 269650    47.0
# 269992    46.0
# 269993    46.0
# 269994    46.0
# 269995    46.0
# 269996    46.0
# 269997    46.0
# 269998    49.0
# 269999    49.0
# 270199    58.0
# 270200    58.0
# 270352    45.0
# 270561    44.0
# 270955    41.0
# 271034    36.0
# Name: Age, Length: 3071, dtype: float64

# %%
# where were the art competitions?
events_df[events_df['Sport']=='Art Competitions']['City'].value_counts()
# Out:
# Los Angeles    1124
# Berlin          813
# Amsterdam       808
# London          471
# Paris           318
# Stockholm        33
# Antwerpen        11
# Name: City, dtype: int64

# %%
# what events were held for the art competitions?
events_df[events_df['Sport']=='Art Competitions']['Event'].value_counts()
# Out:
# Art Competitions Mixed Painting, Unknown Event                    1074
# Art Competitions Mixed Sculpturing, Unknown Event                  452
# Art Competitions Mixed Painting, Paintings                         309
# Art Competitions Mixed Sculpturing, Statues                        203
# Art Competitions Mixed Architecture, Architectural Designs         190
# Art Competitions Mixed Architecture, Designs For Town Planning     163
# Art Competitions Mixed Sculpturing                                 162
# Art Competitions Mixed Architecture, Unknown Event                 150
# Art Competitions Mixed Painting, Drawings And Water Colors         145
# Art Competitions Mixed Painting                                    112
# Art Competitions Mixed Painting, Graphic Arts                       83
# Art Competitions Mixed Painting, Applied Arts                       75
# Art Competitions Mixed Literature                                   60
# Art Competitions Mixed Music                                        53
# Art Competitions Mixed Sculpturing, Medals And Reliefs              43
# Art Competitions Mixed Literature, Unknown Event                    39
# Art Competitions Mixed Sculpturing, Medals                          38
# Art Competitions Mixed Literature, Lyric Works                      34
# Art Competitions Mixed Music, Compositions For Orchestra            34
# Art Competitions Mixed Architecture                                 32
# Art Competitions Mixed Literature, Epic Works                       27
# Art Competitions Mixed Unknown Event                                26
# Art Competitions Mixed Music, Unknown Event                         18
# Art Competitions Mixed Music, Instrumental And Chamber              13
# Art Competitions Mixed Sculpturing, Reliefs                         11
# Art Competitions Mixed Sculpturing, Medals And Plaques              10
# Art Competitions Mixed Music, Compositions For Solo Or Chorus        9
# Art Competitions Mixed Literature, Dramatic Works                    8
# Art Competitions Mixed Music, Vocals                                 5
# Name: Event, dtype: int64

# %%
# on the subject of art competitions, what is the age distribution of the participants?
art_age = events_df[events_df['Sport']=='Art Competitions']['Age'].value_counts(normalize=True)

# TODO: change to histogram and account for NaN values

# plotting
plt.bar(all_age.index, all_age.values, label='all athletes', alpha=0.6)
plt.bar(art_age.index, art_age.values, label='art competitors', alpha=0.6)
plt.title('Age Distribution of Art Competition Athletes')
plt.xlabel('Age')
plt.ylabel('Count')
plt.legend()

# %%
# what country most successfull at the art competitions?
events_df[(events_df['Sport']=='Art Competitions') & (events_df['Medal'].notnull())]['Team'].value_counts()
# Out:
# Germany           26
# France            15
# Italy             14
# Austria           10
# Great Britain      9
# Denmark            9
# United States      9
# Switzerland        9
# Belgium            8
# Poland             8
# Netherlands        7
# Hungary            5
# Finland            5
# Sweden             4
# Ireland            3
# Luxembourg         3
# Czechoslovakia     3
# Japan              2
# South Africa       2
# Canada             2
# Monaco             1
# Norway             1
# Greece             1
# Name: Team, dtype: int64

# %%
# reviewing the Berlin art competition further
berlin_art = events_df[(events_df['Sport']=='Art Competitions') & (events_df['City']=='Berlin')]
berlin_art.head()
# Out:
#         ID                               Name Sex   Age  Height  Weight  \
# 4866  2777             Hermann Reinhard Alker   M  51.0     NaN     NaN
# 4867  2777             Hermann Reinhard Alker   M  51.0     NaN     NaN
# 5304  3002  Kasper Angarius "Ansgar" Almquist   M  47.0     NaN     NaN
# 6009  3375                       Sndor Ambrzy   M  32.0     NaN     NaN
# 7496  4188                    Ferdinand Andri   M  65.0     NaN     NaN
#
#          Team  NOC        Games  Year  Season    City             Sport  \
# 4866  Germany  GER  1936 Summer  1936  Summer  Berlin  Art Competitions
# 4867  Germany  GER  1936 Summer  1936  Summer  Berlin  Art Competitions
# 5304   Sweden  SWE  1936 Summer  1936  Summer  Berlin  Art Competitions
# 6009  Hungary  HUN  1936 Summer  1936  Summer  Berlin  Art Competitions
# 7496  Austria  AUT  1936 Summer  1936  Summer  Berlin  Art Competitions
#
#                                                   Event Medal
# 4866  Art Competitions Mixed Architecture, Unknown E...   NaN
# 4867  Art Competitions Mixed Architecture, Unknown E...   NaN
# 5304        Art Competitions Mixed Sculpturing, Statues   NaN
# 6009        Art Competitions Mixed Sculpturing, Statues   NaN
# 7496  Art Competitions Mixed Architecture, Unknown E...   NaN

# %%
# counting medals for berlin olympics, art
berlin_art_medals = berlin_art[berlin_art['Medal'].notnull()].groupby(['Team'])['Medal'].value_counts().unstack()
berlin_art_medals.head()
# Out:
# Medal           Bronze  Gold  Silver
# Team
# Austria            3.0   1.0     1.0
# Belgium            1.0   NaN     NaN
# Czechoslovakia     1.0   NaN     NaN
# Finland            NaN   1.0     NaN
# Germany            2.0   6.0     6.0

# %%
# stacked bar chart

# ordering by total medals 
total_medals = berlin_art_medals.sum(axis=1)
berlin_art_medals['total'] = total_medals
berlin_art_medals = berlin_art_medals.sort_values('total', ascending=False)
berlin_art_medals = berlin_art_medals[['Bronze', 'Silver', 'Gold']]

# plotting
berlin_art_medals.plot(kind='bar', stacked=True, color=['burlywood', 'silver', 'gold'])
plt.ylabel('Medal Count')
plt.title('Berlin 1938 Olympics Art Competitions')
# Out:
# Text(0.5,1,'Berlin 1938 Olympics Art Competitions')

# %% [markdown]
# ### 1936 olympics, Berlin
# * under the nazi regime

# %%
berlin_df = events_df[events_df['Year']==1936]
berlin_df.head()
# Out:
#       ID               Name Sex   Age  Height  Weight     Team  NOC  \
# 94    31  Evald rma (rman-)   M  24.0   174.0    70.0  Estonia  EST
# 124   45        Hakon Aasns   M  41.0     NaN     NaN   Norway  NOR
# 125   46         Hans Aasns   M  33.0   194.0    93.0   Norway  NOR
# 209  100   Oszkr Abay-Nemes   M  22.0     NaN     NaN  Hungary  HUN
# 210  100   Oszkr Abay-Nemes   M  22.0     NaN     NaN  Hungary  HUN
#
#            Games  Year  Season    City      Sport  \
# 94   1936 Summer  1936  Summer  Berlin  Athletics
# 124  1936 Summer  1936  Summer  Berlin   Shooting
# 125  1936 Summer  1936  Summer  Berlin   Shooting
# 209  1936 Summer  1936  Summer  Berlin   Swimming
# 210  1936 Summer  1936  Summer  Berlin   Swimming
#
#                                                  Event   Medal
# 94                          Athletics Men's Pole Vault     NaN
# 124  Shooting Men's Small-Bore Rifle, Prone, 50 metres     NaN
# 125        Shooting Men's Rapid-Fire Pistol, 25 metres     NaN
# 209                Swimming Men's 100 metres Freestyle     NaN
# 210      Swimming Men's 4 x 200 metres Freestyle Relay  Bronze

# %%
# which sports did germany do best in?
berlin_df[(berlin_df['Team']=='Germany') & (berlin_df['Medal'].notnull())]['Sport'].value_counts()

# result: art competitions are fairly high up
# Out:
# Gymnastics           27
# Rowing               26
# Handball             22
# Hockey               22
# Athletics            22
# Art Competitions     14
# Equestrianism        13
# Fencing              13
# Water Polo           11
# Canoeing             10
# Swimming              8
# Wrestling             7
# Weightlifting         5
# Boxing                5
# Cycling               4
# Alpine Skiing         4
# Shooting              3
# Diving                2
# Figure Skating        1
# Modern Pentathlon     1
# Name: Sport, dtype: int64

# %% [markdown]
# # exploring missing values for height and weight

# %%
# number of participants
total_no = merged_df.groupby(['Year']).count()['ID']

# number of participants with height and weight data
total_no_with_hw = merged_df[(merged_df['Height'].notnull()) & (merged_df['Weight'].notnull())].groupby('Year')['ID'].count()

# total percentage of athletes with height and weight data
percent_with_hw = (total_no_with_hw/total_no) * 100

# %%
# plotting
fig, ax1 = plt.subplots()

ax1.plot(percent_with_hw, 'x-', label='percent w/ height and weight', color='k')
ax1.legend(loc='upper left')
ax1.set_ylabel("Athletes w/ Height \& Weight Data (\%)")
ax1.set_xlabel('Year')

ax2 = ax1.twinx()
ax2.plot(total_no, '--x', alpha=0.6, label='total no. of athletes')
ax2.plot(total_no_with_hw, '--x', alpha=0.6, label='no. of athletes height and weight')
ax2.legend(loc='lower right')
ax2.set_ylabel('Count', color='#1f77b4')
ax2.tick_params('y', colors='#ff7f0e')

plt.title("Missing Height \& Weight Data")

# result: data for height and weight doesn't exist before ~1960
# so: any temporal analysis of height and weight should be done for data following 1960
# Out:
# Text(0.5,1,'Missing Height \\& Weight Data')

# %%
# plotting height and weight data

medalists = merged_df[(merged_df['Medal'].notnull())]

plt.title('Height \& Weight of all Athletes')
plt.scatter(merged_df['Weight'], merged_df['Height'], marker='.', s=3, label='all', alpha=0.8)
# plt.scatter(medalists['Weight'], medalists['Height'], marker='.', color='red', s=3, label='medalists', alpha=0.8)
plt.xlabel('Weight')
plt.ylabel('Height')
# plt.legend()

# mostly linear relationship
# greater variance in height as weight increases (vice-versa), naturally
# height and weight will vary for different sports
# Out:
# Text(0,0.5,'Height')

# %%
sns.jointplot(x="Height", y="Weight", data=medalists, kind="kde", height=5, ratio=3)
# Out:
# /Users/yasirdin/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# year on year height and weight ratio for top 5 sports

# taking data after 1960 for height and weight; given missed data
post_1960 = merged_df[merged_df['Year']>=1960]

# adding height and weight ratio
post_1960['hw_ratio'] = post_1960['Height'] / post_1960['Weight']
post_1960.head()
# Out:
# /Users/yasirdin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#        ID           Name Sex   Age  Height  Weight   Team  NOC        Games  \
# 0     1.0      A Dijiang   M  24.0   180.0    80.0  China  CHN  1992 Summer
# 1     2.0       A Lamusi   M  23.0   170.0    60.0  China  CHN  2012 Summer
# 2   602.0  Abudoureheman   M  22.0   182.0    75.0  China  CHN  2000 Summer
# 3  1463.0      Ai Linuer   M  25.0   160.0    62.0  China  CHN  2004 Summer
# 4  1464.0      Ai Yanhan   F  14.0   168.0    54.0  China  CHN  2016 Summer
#
#      Year  Season            City       Sport  \
# 0  1992.0  Summer       Barcelona  Basketball
# 1  2012.0  Summer          London        Judo
# 2  2000.0  Summer          Sydney      Boxing
# 3  2004.0  Summer          Athina   Wrestling
# 4  2016.0  Summer  Rio de Janeiro    Swimming
#
#                                       Event Medal region notes  hw_ratio
# 0               Basketball Men's Basketball   NaN  China   NaN  2.250000
# 1              Judo Men's Extra-Lightweight   NaN  China   NaN  2.833333
# 2                 Boxing Men's Middleweight   NaN  China   NaN  2.426667
# 3  Wrestling Men's Lightweight, Greco-Roman   NaN  China   NaN  2.580645
# 4     Swimming Women's 200 metres Freestyle   NaN  China   NaN  3.111111

# %%
# taking top 5 most populace sports
top5_sports = merged_df['Sport'].value_counts().iloc[:5].index

# year on year height and weight ratio for top 5 sports
for sport in top5_sports:
    data = post_1960[post_1960['Sport']==sport]
    data = data.groupby(['Year'])['hw_ratio'].mean()
    plt.plot(data.index, data.values, 'x-', label=sport, alpha=0.8)
plt.title('Average Height / Weight Ratio for Top 5 Sports')
plt.xlabel('Year')
plt.ylabel('Height / Weight')
plt.legend()

# %%
# exploring cycling further, looking at the weight of track cycling and road cyclist
post_1960[post_1960['Sport']=='Cycling']['Event'].value_counts()

# road cycling, 
road_cycling = post_1960[post_1960['Event']=="Cycling Men's Road Race, Individual"]
avg_road = road_cycling.groupby(['Year'])['Weight'].mean()
road_se = road_cycling.groupby(['Year'])['Weight'].sem()

# track cycling
track_cycling = post_1960[post_1960['Event']=="Cycling Men's Sprint"]
avg_track = track_cycling.groupby(['Year'])['Weight'].mean()
track_se = track_cycling.groupby(['Year'])['Weight'].sem()

# %%
# plotting
plt.plot(avg_road.index, avg_road.values, 'x-', label='Road')
plt.plot(avg_track.index, avg_track.values, 'x-', label='Track')

# error bars
plt.errorbar(avg_road.index, avg_road.values, road_se, linestyle='None', label='standard error', color='k')
plt.errorbar(avg_track.index, avg_track.values, track_se, linestyle='None', color='k')

plt.title('Weight of Track \& Road Cyclists')
plt.ylabel('Weight (kg)')
plt.xlabel('Year')
plt.legend()

# insert picture of robert forstemann in the slides

# %% [markdown]
# ### Exploring Russian performance at the games
# * After watching Icarus on Netflix (highly recommend!) I'm interested to see how Russia has performed at the olympics
# * Winter games in Sochi (doping scandal)

# %%
# winter and summer olympics
russia_summer = merged_df[(merged_df['region']=='Russia') & (merged_df['Season']=='Summer')]
russia_winter = merged_df[(merged_df['region']=='Russia') & (merged_df['Season']=='Winter')]
russia_winter.head()
# Out:
#           ID                                Name Sex   Age  Height  Weight  \
# 84970  544.0         Sergey Mikhaylovich Abramov   M  34.0   180.0    94.0
# 84971  548.0  Yekaterina Konstantinovna Abramova   F  23.0   167.0    65.0
# 84972  548.0  Yekaterina Konstantinovna Abramova   F  23.0   167.0    65.0
# 84973  548.0  Yekaterina Konstantinovna Abramova   F  23.0   167.0    65.0
# 84974  548.0  Yekaterina Konstantinovna Abramova   F  27.0   167.0    65.0
#
#          Team  NOC        Games    Year  Season         City          Sport  \
# 84970  Russia  RUS  1994 Winter  1994.0  Winter  Lillehammer     Ice Hockey
# 84971  Russia  RUS  2006 Winter  2006.0  Winter       Torino  Speed Skating
# 84972  Russia  RUS  2006 Winter  2006.0  Winter       Torino  Speed Skating
# 84973  Russia  RUS  2006 Winter  2006.0  Winter       Torino  Speed Skating
# 84974  Russia  RUS  2010 Winter  2010.0  Winter    Vancouver  Speed Skating
#
#                                              Event   Medal  region notes
# 84970                  Ice Hockey Men's Ice Hockey     NaN  Russia   NaN
# 84971           Speed Skating Women's 1,000 metres     NaN  Russia   NaN
# 84972           Speed Skating Women's 1,500 metres     NaN  Russia   NaN
# 84973  Speed Skating Women's Team Pursuit (6 laps)  Bronze  Russia   NaN
# 84974           Speed Skating Women's 1,500 metres     NaN  Russia   NaN

# %%
russia_summer_medal = russia_summer[russia_summer['Medal'].notnull()]
summer_medal_count = russia_summer_medal.groupby('Year')['Medal'].count()
plt.plot(summer_medal_count, 'x-')
plt.title('Russian Medal Winnings (Summer Olympics)')
plt.xlabel('Year')
plt.ylabel('No. of Medals')
# Out:
# Text(0,0.5,'No. of Medals')

# %%
russia_winter_medal = russia_winter[russia_winter['Medal'].notnull()]
winter_medal_count = russia_winter_medal.groupby('Year')['Medal'].count()
plt.plot(winter_medal_count, 'x-')
plt.title('Russian Medal Winnings (Winter Olympics)')
plt.xlabel('Year')
plt.ylabel('No. of Medals')
# Out:
# Text(0,0.5,'No. of Medals')

# %%
winter_medal_count
# result: almost 3 times as many medals were won in the following winter olympics in sochi!
# Out:
# Year
# 1956.0    37
# 1960.0    42
# 1964.0    47
# 1968.0    37
# 1972.0    45
# 1976.0    56
# 1980.0    54
# 1984.0    56
# 1988.0    66
# 1992.0    59
# 1994.0    36
# 1998.0    52
# 2002.0    38
# 2006.0    41
# 2010.0    25
# 2014.0    68
# Name: Medal, dtype: int64

# %%
# comparing 2010 winter olympics and 2014 olympics — how similar was the russian team?
winter_2010 = russia_winter[russia_winter['Year']==2010]
winter_2014 = russia_winter[russia_winter['Year']==2014]

# %%
winter_2010.describe()
# Out:
#                   ID         Age      Height      Weight    Year
# count     279.000000  279.000000  279.000000  279.000000   279.0
# mean    84229.168459   25.602151  175.193548   70.946237  2010.0
# std     37006.087110    4.668446    9.055693   13.569988     0.0
# min       548.000000   16.000000  155.000000   38.000000  2010.0
# 25%     59384.000000   22.000000  168.000000   61.000000  2010.0
# 50%     91089.000000   25.000000  175.000000   68.000000  2010.0
# 75%    111937.000000   28.000000  183.000000   80.000000  2010.0
# max    135485.000000   40.000000  199.000000  105.000000  2010.0

# %%
# most successful sports in 2010
print('total medals:', sum(winter_2010[winter_2010['Medal'].notnull()]['Sport'].value_counts()))
winter_2010[winter_2010['Medal'].notnull()]['Sport'].value_counts()
# Out:
# total medals: 25
# Biathlon                10
# Cross Country Skiing     6
# Figure Skating           3
# Bobsleigh                2
# Speed Skating            2
# Skeleton                 1
# Snowboarding             1
# Name: Sport, dtype: int64

# %%
print('total medals:', sum(winter_2014[winter_2014['Medal'].notnull()]['Sport'].value_counts()))
winter_2014[winter_2014['Medal'].notnull()]['Sport'].value_counts()
# Out:
# total medals: 68
# Figure Skating               17
# Biathlon                     10
# Cross Country Skiing          9
# Short Track Speed Skating     8
# Bobsleigh                     6
# Speed Skating                 6
# Luge                          5
# Snowboarding                  4
# Skeleton                      2
# Freestyle Skiing              1
# Name: Sport, dtype: int64

# %%
winter_2014.describe()
# Out:
#                   ID         Age      Height      Weight    Year
# count     353.000000  353.000000  353.000000  333.000000   353.0
# mean    80841.560907   25.932011  175.096317   71.456456  2014.0
# std     41013.716031    4.465896    8.926264   13.001230     0.0
# min      3048.000000   15.000000  157.000000   44.000000  2014.0
# 25%     51929.000000   23.000000  169.000000   62.000000  2014.0
# 50%     86213.000000   26.000000  175.000000   70.000000  2014.0
# 75%    117264.000000   28.000000  181.000000   80.000000  2014.0
# max    135485.000000   42.000000  197.000000  115.000000  2014.0

# %%
# returning athletes
print('returning athletes:', np.count_nonzero(winter_2010['Name'].isin(winter_2014['Name'])))
print('of:', len(list(winter_2010['ID'].unique())), 'athletes')
# Out:
# returning athletes: 131
# of: 175 athletes
